# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def position_func(t):
    return 20*t + 5

# %%
t = np.linspace(0, 10, 100)
t
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, position_func(t),
        color = 'purple',
        lw = 3,
        label = 'Position graph')

plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.legend(loc = 'upper center')

plt.xlabel("Time (in hours)")
plt.ylabel("Distance covered (in km)")

plt.grid(True)

# %%
def get_derivative(f, t, method = 'central', h = 0.0001):
    if method == 'central':
        return(f(t + h) - f(t - h)) / (2 * h)
    
    elif method == 'forward':
        return (f(t + h) - f(t)) / h
    
    elif method == 'backward':
        return (f(t) - f(t - h)) / h
    
    else:
        raise ValueError("Method must be 'central', 'forward' or 'backward'.")

# %%
velocity_5 = get_derivative(position_func, 5)

velocity_5
# Out:
# 19.99999999995339

# %%
velocity_10 = get_derivative(position_func, 10)

velocity_10
# Out:
# 20.000000000095497

# %%
from scipy.misc import derivative

# %%
derivative(position_func, 5)
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\2835517044.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(position_func, 5)
# 20.0

# %%
derivative(position_func, 10)
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\3416142281.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   derivative(position_func, 10)
# 20.0

# %%
def get_velocity(t):
    
    return derivative(position_func, t)

# %%
t_1 = 4

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, position_func(t),
        color = 'purple',
        lw = 3,
        label = 'Distance graph')

plt.plot(t, get_velocity(t),
        color = 'green',
        lw = 3,
        label = 'Velocity graph')

plt.scatter(t_1, derivative(position_func, t_1),
           color = 'red',
           lw = 5,
           label = r'$VelocityAtTime (t_1) = 4hours$')

plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.legend(loc = 'upper center')

plt.xlabel("Time (in hours)")

plt.grid(True)
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\3483025501.py:3: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   return derivative(position_func, t)
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\900551056.py:13: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.scatter(t_1, derivative(position_func, t_1),

# %%
import sympy as sp

# %%
t = sp.Symbol('t')
t
# Out:
# t

# %%
position_eq = 2*t + 5
position_eq
# Out:
# 2*t + 5

# %%
velocity_eq = sp.diff(position_eq, t)
velocity_eq
# Out:
# 2

# %%
# Interpreting the Derivative as the Slope of a Tangent Line

# %%
x = np.linspace(-10, 10, 100)

# %%
def f(x):
    return x**2 + 0*x + 0

# %%
plt.figure(figsize = (12, 6))

plt.plot(x, f(x),
        color = 'purple',
        lw = 2,
        label = 'Error')

plt.xlim(-12, 12)
plt.ylim(0, 100)

plt.xlabel("x")
plt.ylabel("Error")
plt.legend(loc = 'upper center')
plt.grid(True)
plt.show()

# %%
def tangent_line(x, x1, y1):
    m = derivative(f, x1)
    
    return m * (x - x1) + y1

# %%
x1 = 5
y1 = f(x1)

# %%
print(f'What will be the rate of change of error at {x1, y1}? = {derivative(f,x1)}')
# Out:
# What will be the rate of change of error at (5, 25)? = 10.0
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\1162999450.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   print(f'What will be the rate of change of error at {x1, y1}? = {derivative(f,x1)}')

# %%
#define t range for tangent
x_range = np.linspace(x1 - 5, x1 + 5, 100)

# %%
plt.figure(figsize = (12, 6))

plt.plot(x, f(x),
        color = 'purple',
        lw = 2,
        label = 'Error')

plt.scatter(x1, y1, color = 'green', s = 50)

plt.plot(x_range, tangent_line(x_range, x1, y1),
         linestyle = '--',
        color = 'darkgreen',
        lw = 2,
        label = 'Tangent')

plt.xlim(-10, 10)
plt.ylim(0, 100)

plt.xlabel("x")
plt.ylabel("Error")

plt.legend(loc = 'upper center')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\1312661050.py:2: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   m = derivative(f, x1)

# %%
# Interpreting the Velocity of an Accelerating Particle

# %%
x2 = 2
y2 = f(x2)

# %%
print(f'What will be the rate of change of error at {x2, y2}? = {derivative(f,x2)}')
# Out:
# What will be the rate of change of error at (2, 4)? = 4.0
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\2603629533.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   print(f'What will be the rate of change of error at {x2, y2}? = {derivative(f,x2)}')

# %%
#define t range for tangent

x_range = np.linspace(x2 - 3, x2 + 3, 100)

# %%
plt.figure(figsize = (12, 6))

plt.plot(x, f(x),
        color = 'purple',
        lw = 2,
        label = 'Error')

plt.scatter(x2, y2, color = 'green', s = 50)

plt.plot(x_range, tangent_line(x_range, x2, y2),
         linestyle = '--',
        color = 'darkgreen',
        lw = 2,
        label = 'Tangent')

plt.xlim(-10, 10)
plt.ylim(0, 100)

plt.xlabel("x")
plt.ylabel("Error")

plt.legend(loc = 'upper center')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\1312661050.py:2: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   m = derivative(f, x1)

# %%
t = np.linspace(0, 10, 100)

# %%
def position_func(t):
    return 8*t**2 + 2*t + 1

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, position_func(t),
        color = 'purple',
        lw = 3,
        label = 'Position')

plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.legend(loc = 'center right')

plt.xlabel("Time (in sec)")
plt.ylabel("Distance covered (in meters)")

plt.grid(True)

# %%
t1 = 4
y1 = position_func(t1)

# %%
print(f'What will be velocity at {t1, y1}? = {derivative(position_func, t1)}')
# Out:
# What will be velocity at (4, 137)? = 66.0
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\818729988.py:1: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   print(f'What will be velocity at {t1, y1}? = {derivative(position_func, t1)}')

# %%
def tangent_line(t, t1, y1):
    m = derivative(position_func, t1)
    
    return m * (t - t1) + y1

# %%
t_range = np.linspace(t1 - 3, t1 + 3, 100)

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, position_func(t),
        color = 'purple',
        lw = 2,
        label = 'Position')

plt.scatter(t1, y1, color = 'green', s = 70)

plt.plot(t_range, tangent_line(t_range, t1, y1),
         linestyle = '--',
        color = 'darkgreen',
        lw = 2.5,
        label = 'Velocity of moving partical a at time t')

plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.xlabel("Time (in sec)")
plt.ylabel("Position (in meters)")
plt.legend(loc = 'upper center')

plt.grid(True)
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\3006025387.py:2: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   m = derivative(position_func, t1)

# %%
#Modeling Velocity and Trajectory

# %%
t = sp.Symbol('t')

# %%
position_eq = 8*t**2 + 2*t + 1
position_eq
# Out:
# 8*t**2 + 2*t + 1

# %%
velocity_eq = sp.diff(position_eq, t)
velocity_eq
# Out:
# 16*t + 2

# %%
velocity_eq.subs(t, 1)
# Out:
# 18

# %%
velocity_eq.subs(t, 5)
# Out:
# 82

# %%
velocity_eq.subs(t, 10)
# Out:
# 162

# %%
def particle_trace(t):
    
    return -t**3 + 8*t**2 + 2*t + 1

# %%
t = np.linspace(0,8.25)

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, particle_trace(t),
        color = 'purple',
        lw = 2,
        label = 'Particle trajectory')


plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.legend(loc = 'upper center')

plt.xlabel("Time (in sec)")
plt.ylabel("Distance covered (in meters)")


plt.grid(True)

# %%
plt.figure(figsize = (12, 6))

plt.plot(t, particle_trace(t),
        color = 'purple',
        lw = 2,
        label = 'Particle trajectory')

plt.plot(t, derivative(particle_trace, t),
        color = 'green',
        lw = 3,
        label = 'Particle velocity')

plt.scatter(t_1, derivative(particle_trace, t_1),
           color = 'red',
           lw = 5,
           label = r'$VelocityAtTime (t_1) = 4sec$')

plt.gca().spines['left'].set_position('zero',)
plt.gca().spines['bottom'].set_position('zero',)

plt.legend(loc = 'upper right')

plt.xlabel("Time (in sec)")



plt.grid(True)
# Out:
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\3818496605.py:8: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.plot(t, derivative(particle_trace, t),
# C:\Users\Iris2812052\AppData\Local\Temp\ipykernel_13132\3818496605.py:13: DeprecationWarning: scipy.misc.derivative is deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. You may consider using findiff: https://github.com/maroba/findiff or numdifftools: https://github.com/pbrod/numdifftools
#   plt.scatter(t_1, derivative(particle_trace, t_1),

# %%
t = sp.Symbol('t')

# %%
particle_trace_eq = -t**3 + 8*t**2 + 2*t + 1

particle_trace_eq
# Out:
# -t**3 + 8*t**2 + 2*t + 1

# %%
particle_velocity = sp.diff(particle_trace_eq, t)

particle_velocity
# Out:
# -3*t**2 + 16*t + 2

# %%
particle_velocity.subs(t,2)
# Out:
# 22

# %%
particle_velocity.subs(t,3)
# Out:
# 23

# %%
particle_velocity.subs(t, 5.45)
# Out:
# 0.0925000000000011

# %%
particle_velocity.subs(t, 7)
# Out:
# -33

# %%
particle_velocity.subs(t, 10)
# Out:
# -138
